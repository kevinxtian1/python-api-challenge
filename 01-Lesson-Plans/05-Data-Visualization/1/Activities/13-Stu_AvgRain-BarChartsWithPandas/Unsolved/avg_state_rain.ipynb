# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("../Resources/avg_rain_state.csv")
df.head()
# Out:
#         State  Inches  Millimetres
# 0      Alaska    43.2         1098
# 1     Alabama    58.9         1495
# 2    Arkansas    55.9         1421
# 3     Arizona    12.6          321
# 4  California    22.2          564

# %%
# Load in csv
# Out:
#         State  Inches  Millimetres
# 0      Alaska    43.2         1098
# 1     Alabama    58.9         1495
# 2    Arkansas    55.9         1421
# 3     Arizona    12.6          321
# 4  California    22.2          564

# %%
tick_locations = [x for x in range(len(list(df["State"])))]
# x_axis

# %%
# Out:
# 49

# %%
# Set x axis and tick locations
# x_axis = df["State"]

# %%
plt.figure(figsize=[20, 5])
plt.bar(x_axis, df["Inches"], color="red", alpha=0.5)
plt.xticks(tick_locations, df["State"], rotation="vertical")
plt.xlim(np.min(tick_locations)-0.5, np.max(tick_locations)+0.5)
plt.ylim(df["Inches"].min()-2, df["Inches"].max()+0.5)
# Set a Title and labels
plt.title("Average Rain")
plt.xlabel("State")
plt.xlabel("Average Amount in Inches")
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="2000">

# %%
# Create a list indicating where to write x labels and set figure size to adjust for space
# Out:
# <img src="data:image/png;base64,..." width="2000">

# %%
# Set x and y limits

# %%
# Save our graph and show the graph
plt.savefig("found.png")
